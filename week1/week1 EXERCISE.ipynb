# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os

from typing import List
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# constants
MODEL = 'gpt-5-nano'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')
if api_key and api_key.startswith('sk-proj-') and len(api_key) > 10:
  print('API key looks good!')
else: print('There might be a problem with the API Key!')

openai = OpenAI()
# Out:
# API key looks good!

# %%
# here is the question; type over this to ask something new

question = """
what does an llm engineer do in real life jobs?
assume that the person you are explaining to has some IT background but not specifically in AI
"""

# %%
# Get gpt-4o-mini to answer, with streaming
system_propmt = """"
You are a senior LLM engineer with a PHD degree in AI Engineering working in one of the biggest AI companies and wants to show new generation how to become like you
"""

stream = openai.chat.completions.create(model=MODEL, messages=[
  {'role': 'system', 'content': system_propmt},
  {'role': 'user', 'content': question},
],
stream=True
)

response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
  response += chunk.choices[0].delta.content or ''
  update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# Short answer
# An LLM engineer designs, builds, and maintains systems that use large language models to solve business problems. You typically work at the intersection of software engineering, ML research, and product, delivering real, usable AI features (like chat assistants, document QA, or code copilots) that run in production.
#
# What an LLM engineer does in real life (practical view)
#
# 1) Frame problems and design the system
# - Understand business goals and success metrics (e.g., user satisfaction, time saved, reduction in support tickets).
# - Decide whether to use a base LLM, fine-tune, or use retrieval augmented generation (RAG) with a knowledge base.
# - Design the end-to-end flow: data sources, prompts, model choice, retrieval, caching, and the API surface.
#
# 2) Data and prompts
# - Gather and scrub data: user queries, docs, internal wikis, logs.
# - Create and test prompts and instruction sets; iterate on prompt templates for consistency.
# ...

# %%
# Get Llama 3.2 to answer
